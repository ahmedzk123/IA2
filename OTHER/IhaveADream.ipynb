# %% [markdown]
# Hello, My name is Ahmed, here are some of the issues I wanna solve:
#
# - I wanna turn regular iphone camera images into high -res professioanl images
#
# - I wanna make a text generator, basically me for IG/snap/texts
#
# - I wanna make a spam job applier thats end to end
#     - it automatically scans and finds jobs
#     - it then appleis to eah of them
#     - adjusts cover letter
#
# - I wanna learn CyberSec

# %%
import random 
import numpy as np 



random.seed(23)

ideas = ['ImageRes', 'TextGen', 'SpamApplier']

random_num = random.randint(0,2)

ideas[random_num]
# Out:
# 'TextGen'

# %% [markdown]
# I guess were running text generation
